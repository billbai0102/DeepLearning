# %%
import torch
from torch import nn
from torch import optim
from torch.utils.data import DataLoader
import torchvision
from torchvision import datasets
from torchvision import transforms
from torchvision.utils import save_image
from torchsummary import summary

import os
import numpy as np
from IPython.display import display
import matplotlib.pyplot as plt

from hyperparameters import *
from Generator import Generator
from Discriminator import Discriminator

np.random.seed(0)
torch.cuda.manual_seed(0)

# %%
ds = datasets.ImageFolder(
    root=IMG_PATH
    , transform=transforms.Compose([
        transforms.Resize(SZ)
        , transforms.CenterCrop(SZ)
        , transforms.ToTensor()
        , transforms.Normalize((.5, .5, .5), (.5, .5, .5))
    ])
)

dl = DataLoader(ds, batch_size=BATCH_SZ, shuffle=True, num_workers=4)

# %%
for data, target in dl:
    data, target = data[0].numpy().transpose(1, 2, 0), target[0]
    display(plt.imshow(data))
    print(f'Label: {target}')
    break
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Label: 0

# %%
def init_weights(cls):
    cls_name = cls.__class__.__name__

    # init weights for conv tensors
    if cls_name.find('Conv') != -1:
        cls.weight.data.normal_(0.0, 0.02)

    # init weights for batch normalization tensors
    elif cls_name.find('BatchNorm') != -1:
        cls.weight.data.normal_(1.0, 0.02)
        cls.bias.data.fill_(0)

# %%
# create Generator instance and move to cuda
gen = Generator().cuda()
# create Discriminator instance and move to cuda
dis = Discriminator().cuda()

# apply init_weights() to all layers
gen.apply(init_weights)
dis.apply(init_weights)

# print summaries
print('-'*5 + 'Generator' + '-'*5)
display(summary(gen, input_size=(100, 1, 1)))
print('\n' + '-'*5 + 'Discriminator' + '-'*5)
display(summary(dis, input_size=(3, 100, 100)))
# Out:
# -----Generator-----
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#    ConvTranspose2d-1            [-1, 512, 4, 4]         819,200
#        BatchNorm2d-2            [-1, 512, 4, 4]           1,024
#          LeakyReLU-3            [-1, 512, 4, 4]               0
#    ConvTranspose2d-4            [-1, 256, 8, 8]       2,097,152
#        BatchNorm2d-5            [-1, 256, 8, 8]             512
#          LeakyReLU-6            [-1, 256, 8, 8]               0
#    ConvTranspose2d-7          [-1, 128, 16, 16]         524,288
#        BatchNorm2d-8          [-1, 128, 16, 16]             256
#          LeakyReLU-9          [-1, 128, 16, 16]               0
#   ConvTranspose2d-10           [-1, 64, 32, 32]         131,072
#       BatchNorm2d-11           [-1, 64, 32, 32]             128
#         LeakyReLU-12           [-1, 64, 32, 32]               0
#   ConvTranspose2d-13            [-1, 3, 64, 64]           3,072
#              Tanh-14            [-1, 3, 64, 64]               0
# ================================================================
# Total params: 3,576,704
# Trainable params: 3,576,704
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 3.00
# Params size (MB): 13.64
# Estimated Total Size (MB): 16.64
# ----------------------------------------------------------------
# None
# -----Discriminator-----
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 50, 50]           3,072
#          LeakyReLU-2           [-1, 64, 50, 50]               0
#             Conv2d-3          [-1, 128, 25, 25]         131,072
#        BatchNorm2d-4          [-1, 128, 25, 25]             256
#          LeakyReLU-5          [-1, 128, 25, 25]               0
#             Conv2d-6          [-1, 256, 12, 12]         524,288
#        BatchNorm2d-7          [-1, 256, 12, 12]             512
#          LeakyReLU-8          [-1, 256, 12, 12]               0
#             Conv2d-9            [-1, 512, 6, 6]       2,097,152
#       BatchNorm2d-10            [-1, 512, 6, 6]           1,024
#         LeakyReLU-11            [-1, 512, 6, 6]               0
#            Conv2d-12              [-1, 1, 3, 3]           8,192
#           Sigmoid-13              [-1, 1, 3, 3]               0
# ================================================================
# Total params: 2,765,568
# Trainable params: 2,765,568
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.11
# Forward/backward pass size (MB): 5.54
# Params size (MB): 10.55
# Estimated Total Size (MB): 16.20
# ----------------------------------------------------------------
# None

# %%
criterion = nn.BCELoss()
d_opt = optim.Adam(dis.parameters(), lr=LR, betas=(0.88, 0.99))
g_opt = optim.Adam(gen.parameters(), lr=LR, betas=(0.88, 0.99))

# %%
sample_noise = torch.randn(BATCH_SZ, GEN_IN, 1, 1).cuda()
print(sample_noise.shape)
# Out:
# torch.Size([64, 100, 1, 1])

# %%
history = {
'd_loss_real': [],
'd_loss_fake': [],
'd_acc': [],
'g_loss': [],
}

D_BEST_LOSS = float('inf')
G_BEST_LOSS = float('inf')

for epoch in range(EPOCHS):
    for idx, (data, target) in enumerate(dl):
        # move data and target to cuda
        data, target = data.cuda(), target.cuda()
        # create tensors for real and fake targets (1 / 0)
        data_real = data
        target_real = torch.full((data_real.size(0), ), REAL_TARGET).cuda()
        target_fake = torch.full((data_real.size(0), ), FAKE_TARGET).cuda()

        # Train discriminator on **REAL** data
        dis.zero_grad()
        pred_real = dis(data_real)
        d_loss_real = criterion(pred_real, target_real)
        d_loss_real.backward()

        # Train discriminator on **FAKE** data
        gen_noise = torch.randn(data_real.size(0), GEN_IN, 1, 1).cuda()
        data_fake = gen(gen_noise)
        pred_fake = dis(data_fake.detach())
        d_loss_fake = criterion(pred_fake, target_fake)
        d_loss_fake.backward()
        d_opt.step()

        # Train generator on fake data
        gen.zero_grad()
        gen_fake = dis(data_fake)
        g_loss = criterion(gen_fake, target_real)
        g_loss.backward()
        g_opt.step()

        # calculate mean losses
        d_loss_fake = d_loss_fake.mean().item()
        d_loss_real = d_loss_real.mean().item()
        g_loss = g_loss.mean().item()

        # Add loss to history
        history['d_loss_real'].append(d_loss_real)
        history['d_loss_fake'].append(d_loss_fake)
        history['g_loss'].append(g_loss)

        if idx % 100 == 0:

            # save progress images
            save_image(data_real, './progress_images/real_sample.png', normalize=True)
            with torch.no_grad():
                sample_img = gen(sample_noise)
                save_image(sample_img, f'./progress_images/gen_sample{epoch}.png', normalize=True)

            # print status updates
            print(f'\n-----Epoch: {epoch + 1}/{EPOCHS} Batch: {idx}/{BATCH_SZ}-----'
                  f'\nDiscriminator loss on real data: {d_loss_real:.4f}'
                  f'\nDiscriminator loss on fake data: {d_loss_fake:.4f}'
                  f'\nGenerator loss: {g_loss:.4f}')

        torch.save(dis.state_dict(), f'./models/discriminator{epoch}.pt')
        torch.save(gen.state_dict(), f'./models/generator{epoch}.pt')
# Out:
# -----Epoch: 1/75 Batch: 0/64-----
# Discriminator loss on real data: 0.0706
# Discriminator loss on fake data: 0.0012
# Generator loss: 14.7949
#
# -----Epoch: 1/75 Batch: 100/64-----
# Discriminator loss on real data: 0.0918
# Discriminator loss on fake data: 0.0011
# Generator loss: 14.4305
#
# -----Epoch: 1/75 Batch: 200/64-----
# Discriminator loss on real data: 0.5367
# Discriminator loss on fake data: 0.0049
# Generator loss: 7.6830
#
# -----Epoch: 1/75 Batch: 300/64-----
# Discriminator loss on real data: 0.0268
# Discriminator loss on fake data: 0.0006
# Generator loss: 12.5989
#
# -----Epoch: 1/75 Batch: 400/64-----
# Discriminator loss on real data: 0.0205
# Discriminator loss on fake data: 0.0318
# Generator loss: 9.3101
#
# -----Epoch: 1/75 Batch: 500/64-----
# Discriminator loss on real data: 0.1205
# Discriminator loss on fake data: 0.0278
# Generator loss: 9.1847
#
# -----Epoch: 1/75 Batch: 600/64-----
# Discriminator loss on real data: 0.0448
# Discriminator loss on fake data: 0.0361
# Generator loss: 6.9902
#
# -----Epoch: 1/75 Batch: 700/64-----
# Discriminator loss on real data: 0.0019
# Discriminator loss on fake data: 0.1149
# Generator loss: 11.3022
#
# -----Epoch: 1/75 Batch: 800/64-----
# Discriminator loss on real data: 0.0730
# Discriminator loss on fake data: 0.0000
# Generator loss: 13.0020
#
# -----Epoch: 1/75 Batch: 900/64-----
# Discriminator loss on real data: 0.3143
# Discriminator loss on fake data: 0.0234
# Generator loss: 5.0504
#
# -----Epoch: 1/75 Batch: 1000/64-----
# Discriminator loss on real data: 0.0063
# Discriminator loss on fake data: 0.0528
# Generator loss: 9.4809
#
# -----Epoch: 1/75 Batch: 1100/64-----
# Discriminator loss on real data: 0.0009
# Discriminator loss on fake data: 0.0037
# Generator loss: 10.0677
#
# -----Epoch: 1/75 Batch: 1200/64-----
# Discriminator loss on real data: 0.0068
# Discriminator loss on fake data: 0.0003
# Generator loss: 16.5072
#
# -----Epoch: 1/75 Batch: 1300/64-----
# Discriminator loss on real data: 0.2090
# Discriminator loss on fake data: 0.0001
# Generator loss: 11.2727
#
# -----Epoch: 1/75 Batch: 1400/64-----
# Discriminator loss on real data: 0.0013
# Discriminator loss on fake data: 0.0590
# Generator loss: 9.2006
#
# -----Epoch: 1/75 Batch: 1500/64-----
# Discriminator loss on real data: 0.0210
# Discriminator loss on fake data: 0.0923
# Generator loss: 7.9687
#
# -----Epoch: 1/75 Batch: 1600/64-----
# Discriminator loss on real data: 0.0070
# Discriminator loss on fake data: 0.2753
# Generator loss: 8.0069
#
# -----Epoch: 1/75 Batch: 1700/64-----
# Discriminator loss on real data: 0.0144
# Discriminator loss on fake data: 0.0049
# Generator loss: 8.4489
#
# -----Epoch: 1/75 Batch: 1800/64-----
# Discriminator loss on real data: 0.0597
# Discriminator loss on fake data: 0.0001
# Generator loss: 18.5692
#
# -----Epoch: 1/75 Batch: 1900/64-----
# Discriminator loss on real data: 0.0519
# Discriminator loss on fake data: 0.0234
# Generator loss: 7.5128
#
# -----Epoch: 1/75 Batch: 2000/64-----
# Discriminator loss on real data: 0.0730
# Discriminator loss on fake data: 0.0116
# Generator loss: 6.4785
#
# -----Epoch: 1/75 Batch: 2100/64-----
# Discriminator loss on real data: 0.1063
# Discriminator loss on fake data: 0.0047
# Generator loss: 11.9692
#
# -----Epoch: 1/75 Batch: 2200/64-----
# Discriminator loss on real data: 0.0109
# Discriminator loss on fake data: 0.0516
# Generator loss: 8.1564
#
# -----Epoch: 1/75 Batch: 2300/64-----
# Discriminator loss on real data: 0.0816
# Discriminator loss on fake data: 0.0003
# Generator loss: 10.8169
#
# -----Epoch: 1/75 Batch: 2400/64-----
# Discriminator loss on real data: 0.0026
# Discriminator loss on fake data: 0.1389
# Generator loss: 9.1039
#
# -----Epoch: 1/75 Batch: 2500/64-----
# Discriminator loss on real data: 0.0016
# Discriminator loss on fake data: 0.0002
# Generator loss: 13.2598
#
# -----Epoch: 1/75 Batch: 2600/64-----
# Discriminator loss on real data: 0.0182
# Discriminator loss on fake data: 0.0001
# Generator loss: 13.4068
#
# -----Epoch: 1/75 Batch: 2700/64-----
# Discriminator loss on real data: 0.0463
# Discriminator loss on fake data: 0.1423
# Generator loss: 7.4138
#
# -----Epoch: 1/75 Batch: 2800/64-----
# Discriminator loss on real data: 0.0010
# Discriminator loss on fake data: 0.0455
# Generator loss: 8.1651
#
# -----Epoch: 1/75 Batch: 2900/64-----
# Discriminator loss on real data: 0.0003
# Discriminator loss on fake data: 0.0411
# Generator loss: 8.7103
#
# -----Epoch: 1/75 Batch: 3000/64-----
# Discriminator loss on real data: 0.0490
# Discriminator loss on fake data: 0.0018
# Generator loss: 11.2829
#
# -----Epoch: 1/75 Batch: 3100/64-----
# Discriminator loss on real data: 0.0191
# Discriminator loss on fake data: 0.0078
# Generator loss: 6.8589
#
# -----Epoch: 2/75 Batch: 0/64-----
# Discriminator loss on real data: 0.0013
# Discriminator loss on fake data: 0.2342
# Generator loss: 8.4472
#
# -----Epoch: 2/75 Batch: 100/64-----
# Discriminator loss on real data: 0.1594
# Discriminator loss on fake data: 0.0048
# Generator loss: 9.4975
#
# -----Epoch: 2/75 Batch: 200/64-----
# Discriminator loss on real data: 0.0619
# Discriminator loss on fake data: 0.0099
# Generator loss: 8.8133
#
# -----Epoch: 2/75 Batch: 300/64-----
# Discriminator loss on real data: 0.0115
# Discriminator loss on fake data: 0.0035
# Generator loss: 10.2875
#
# -----Epoch: 2/75 Batch: 400/64-----
# Discriminator loss on real data: 0.0430
# Discriminator loss on fake data: 0.0156
# Generator loss: 8.7107
#
# -----Epoch: 2/75 Batch: 500/64-----
# Discriminator loss on real data: 0.0378
# Discriminator loss on fake data: 0.0269
# Generator loss: 7.2059
#
# -----Epoch: 2/75 Batch: 600/64-----
# Discriminator loss on real data: 0.0001
# Discriminator loss on fake data: 0.7354
# Generator loss: 7.2189
#
# -----Epoch: 2/75 Batch: 700/64-----
# Discriminator loss on real data: 0.0010
# Discriminator loss on fake data: 0.0360
# Generator loss: 7.3424
#
# -----Epoch: 2/75 Batch: 800/64-----
# Discriminator loss on real data: 0.0004
# Discriminator loss on fake data: 0.3289
# Generator loss: 10.5812
#
# -----Epoch: 2/75 Batch: 900/64-----
# Discriminator loss on real data: 0.0146
# Discriminator loss on fake data: 0.1405
# Generator loss: 6.4400
#
# -----Epoch: 2/75 Batch: 1000/64-----
# Discriminator loss on real data: 0.1192
# Discriminator loss on fake data: 0.0036
# Generator loss: 10.2537
#
# -----Epoch: 2/75 Batch: 1100/64-----
# Discriminator loss on real data: 0.0116
# Discriminator loss on fake data: 0.0459
# Generator loss: 5.6183
#
# -----Epoch: 2/75 Batch: 1200/64-----
# Discriminator loss on real data: 0.0171
# Discriminator loss on fake data: 0.0208
# Generator loss: 6.4641
#
# -----Epoch: 2/75 Batch: 1300/64-----
# Discriminator loss on real data: 0.0282
# Discriminator loss on fake data: 0.0436
# Generator loss: 7.3616
#
# -----Epoch: 2/75 Batch: 1400/64-----
# Discriminator loss on real data: 0.0031
# Discriminator loss on fake data: 0.0279
# Generator loss: 10.5598
#
# -----Epoch: 2/75 Batch: 1500/64-----
# Discriminator loss on real data: 0.1372
# Discriminator loss on fake data: 0.0098
# Generator loss: 6.7119
#
# -----Epoch: 2/75 Batch: 1600/64-----
# Discriminator loss on real data: 0.5762
# Discriminator loss on fake data: 0.0005
# Generator loss: 8.2299
#
# -----Epoch: 2/75 Batch: 1700/64-----
# Discriminator loss on real data: 0.1513
# Discriminator loss on fake data: 0.0180
# Generator loss: 10.7031
#
# -----Epoch: 2/75 Batch: 1800/64-----
# Discriminator loss on real data: 0.0377
# Discriminator loss on fake data: 0.0478
# Generator loss: 5.4340
#
# -----Epoch: 2/75 Batch: 1900/64-----
# Discriminator loss on real data: 0.0213
# Discriminator loss on fake data: 0.0253
# Generator loss: 5.9572
#
# -----Epoch: 2/75 Batch: 2000/64-----
# Discriminator loss on real data: 0.4706
# Discriminator loss on fake data: 0.0000
# Generator loss: 14.7022
#
# -----Epoch: 2/75 Batch: 2100/64-----
# Discriminator loss on real data: 0.1067
# Discriminator loss on fake data: 0.0121
# Generator loss: 9.8776
#
# -----Epoch: 2/75 Batch: 2200/64-----
# Discriminator loss on real data: 0.0485
# Discriminator loss on fake data: 0.0082
# Generator loss: 10.4205
#
# -----Epoch: 2/75 Batch: 2300/64-----
# Discriminator loss on real data: 0.3590
# Discriminator loss on fake data: 0.0000
# Generator loss: 12.4998
#
# -----Epoch: 2/75 Batch: 2400/64-----
# Discriminator loss on real data: 0.0525
# Discriminator loss on fake data: 0.0033
# Generator loss: 8.0968
#
# -----Epoch: 2/75 Batch: 2500/64-----
# Discriminator loss on real data: 0.0012
# Discriminator loss on fake data: 0.0333
# Generator loss: 9.0033
#
# -----Epoch: 2/75 Batch: 2600/64-----
# Discriminator loss on real data: 0.0683
# Discriminator loss on fake data: 0.0076
# Generator loss: 8.2000
# -----Epoch: 2/75 Batch: 2700/64-----
# Discriminator loss on real data: 0.0292
# Discriminator loss on fake data: 0.0009
# Generator loss: 15.9267
#
# -----Epoch: 2/75 Batch: 2800/64-----
# Discriminator loss on real data: 0.0524
# Discriminator loss on fake data: 0.0329
# Generator loss: 5.4861
#
# -----Epoch: 2/75 Batch: 2900/64-----
# Discriminator loss on real data: 0.2258
# Discriminator loss on fake data: 0.0018
# Generator loss: 8.6912
#
# -----Epoch: 2/75 Batch: 3000/64-----
# Discriminator loss on real data: 0.0013
# Discriminator loss on fake data: 0.0835
# Generator loss: 5.0714
#
# -----Epoch: 2/75 Batch: 3100/64-----
# Discriminator loss on real data: 0.0006
# Discriminator loss on fake data: 0.0411
# Generator loss: 7.1018
#
# -----Epoch: 3/75 Batch: 0/64-----
# Discriminator loss on real data: 0.0196
# Discriminator loss on fake data: 0.2204
# Generator loss: 5.9140
#
# -----Epoch: 3/75 Batch: 100/64-----
# Discriminator loss on real data: 0.0019
# Discriminator loss on fake data: 0.2333
# Generator loss: 7.2662
#
# -----Epoch: 3/75 Batch: 200/64-----
# Discriminator loss on real data: 0.0020
# Discriminator loss on fake data: 0.7506
# Generator loss: 5.1736
#
# -----Epoch: 3/75 Batch: 300/64-----
# Discriminator loss on real data: 0.1050
# Discriminator loss on fake data: 0.0441
# Generator loss: 6.3479
#
# -----Epoch: 3/75 Batch: 400/64-----
# Discriminator loss on real data: 0.0158
# Discriminator loss on fake data: 0.0324
# Generator loss: 6.9662
#
# -----Epoch: 3/75 Batch: 500/64-----
# Discriminator loss on real data: 0.0058
# Discriminator loss on fake data: 0.0483
# Generator loss: 5.8262
#
# -----Epoch: 3/75 Batch: 600/64-----
# Discriminator loss on real data: 0.0132
# Discriminator loss on fake data: 0.0796
# Generator loss: 5.2698
#
# -----Epoch: 3/75 Batch: 700/64-----
# Discriminator loss on real data: 0.0033
# Discriminator loss on fake data: 0.1317
# Generator loss: 6.8291
#
# -----Epoch: 3/75 Batch: 800/64-----
# Discriminator loss on real data: 0.3495
# Discriminator loss on fake data: 0.0260
# Generator loss: 5.3818
#
# -----Epoch: 3/75 Batch: 900/64-----
# Discriminator loss on real data: 0.0073
# Discriminator loss on fake data: 0.0031
# Generator loss: 6.6297
#
# -----Epoch: 3/75 Batch: 1000/64-----
# Discriminator loss on real data: 0.0135
# Discriminator loss on fake data: 0.0674
# Generator loss: 7.3983
#
# -----Epoch: 3/75 Batch: 1100/64-----
# Discriminator loss on real data: 0.0234
# Discriminator loss on fake data: 0.0340
# Generator loss: 4.7857
#
# -----Epoch: 3/75 Batch: 1200/64-----
# Discriminator loss on real data: 0.1775
# Discriminator loss on fake data: 0.0012
# Generator loss: 7.6390
#
# -----Epoch: 3/75 Batch: 1300/64-----
# Discriminator loss on real data: 0.0000
# Discriminator loss on fake data: 0.1674
# Generator loss: 4.2719
#
# -----Epoch: 3/75 Batch: 1400/64-----
# Discriminator loss on real data: 0.1242
# Discriminator loss on fake data: 0.0003
# Generator loss: 8.9134
#
# -----Epoch: 3/75 Batch: 1500/64-----
# Discriminator loss on real data: 0.0033
# Discriminator loss on fake data: 0.2573
# Generator loss: 7.8081
#
# -----Epoch: 3/75 Batch: 1600/64-----
# Discriminator loss on real data: 0.0115
# Discriminator loss on fake data: 0.1061
# Generator loss: 4.4666
#
# -----Epoch: 3/75 Batch: 1700/64-----
# Discriminator loss on real data: 0.2051
# Discriminator loss on fake data: 0.0006
# Generator loss: 8.1402
#
# -----Epoch: 3/75 Batch: 1800/64-----
# Discriminator loss on real data: 0.0051
# Discriminator loss on fake data: 0.0315
# Generator loss: 6.4750
#
# -----Epoch: 3/75 Batch: 1900/64-----
# Discriminator loss on real data: 0.0654
# Discriminator loss on fake data: 0.0530
# Generator loss: 5.1175
#
# -----Epoch: 3/75 Batch: 2000/64-----
# Discriminator loss on real data: 0.0021
# Discriminator loss on fake data: 0.8612
# Generator loss: 5.3498
#
# -----Epoch: 3/75 Batch: 2100/64-----
# Discriminator loss on real data: 0.0409
# Discriminator loss on fake data: 0.0091
# Generator loss: 8.4217
#
# -----Epoch: 3/75 Batch: 2200/64-----
# Discriminator loss on real data: 0.0107
# Discriminator loss on fake data: 0.1189
# Generator loss: 5.9303
#
# -----Epoch: 3/75 Batch: 2300/64-----
# Discriminator loss on real data: 0.0698
# Discriminator loss on fake data: 0.0062
# Generator loss: 7.3119
#
# -----Epoch: 3/75 Batch: 2400/64-----
# Discriminator loss on real data: 0.0109
# Discriminator loss on fake data: 0.2552
# Generator loss: 5.2824
#
# -----Epoch: 3/75 Batch: 2500/64-----
# Discriminator loss on real data: 0.0028
# Discriminator loss on fake data: 0.1856
# Generator loss: 5.3593
#
# -----Epoch: 3/75 Batch: 2600/64-----
# Discriminator loss on real data: 0.0119
# Discriminator loss on fake data: 0.2719
# Generator loss: 5.0735
#
# -----Epoch: 3/75 Batch: 2700/64-----
# Discriminator loss on real data: 0.1738
# Discriminator loss on fake data: 0.0061
# Generator loss: 8.1071
#
# -----Epoch: 3/75 Batch: 2800/64-----
# Discriminator loss on real data: 0.0004
# Discriminator loss on fake data: 0.2092
# Generator loss: 6.5846
#
# -----Epoch: 3/75 Batch: 2900/64-----
# Discriminator loss on real data: 0.0081
# Discriminator loss on fake data: 0.0561
# Generator loss: 5.3515
#
# -----Epoch: 3/75 Batch: 3000/64-----
# Discriminator loss on real data: 0.4886
# Discriminator loss on fake data: 0.0041
# Generator loss: 7.2869
#
# -----Epoch: 3/75 Batch: 3100/64-----
# Discriminator loss on real data: 0.0451
# Discriminator loss on fake data: 0.0195
# Generator loss: 10.5992
#
# -----Epoch: 4/75 Batch: 0/64-----
# Discriminator loss on real data: 0.0368
# Discriminator loss on fake data: 0.0416
# Generator loss: 7.8348
#
# -----Epoch: 4/75 Batch: 100/64-----
# Discriminator loss on real data: 0.0010
# Discriminator loss on fake data: 0.1561
# Generator loss: 4.2804
#
# -----Epoch: 4/75 Batch: 200/64-----
# Discriminator loss on real data: 0.0450
# Discriminator loss on fake data: 0.0016
# Generator loss: 10.8638
#
# -----Epoch: 4/75 Batch: 300/64-----
# Discriminator loss on real data: 0.0048
# Discriminator loss on fake data: 0.0320
# Generator loss: 5.7198
#
# -----Epoch: 4/75 Batch: 400/64-----
# Discriminator loss on real data: 0.0089
# Discriminator loss on fake data: 0.1057
# Generator loss: 5.7358
#
# -----Epoch: 4/75 Batch: 500/64-----
# Discriminator loss on real data: 0.4644
# Discriminator loss on fake data: 0.0037
# Generator loss: 6.9626
#
# -----Epoch: 4/75 Batch: 600/64-----
# Discriminator loss on real data: 0.2663
# Discriminator loss on fake data: 0.0072
# Generator loss: 7.7918
#
# -----Epoch: 4/75 Batch: 700/64-----
# Discriminator loss on real data: 0.0106
# Discriminator loss on fake data: 0.4007
# Generator loss: 5.2904
#
# -----Epoch: 4/75 Batch: 800/64-----
# Discriminator loss on real data: 0.0109
# Discriminator loss on fake data: 0.0047
# Generator loss: 9.5762
#
# -----Epoch: 4/75 Batch: 900/64-----
# Discriminator loss on real data: 0.1475
# Discriminator loss on fake data: 0.0054
# Generator loss: 6.3156
#
# -----Epoch: 4/75 Batch: 1000/64-----
# Discriminator loss on real data: 0.0043
# Discriminator loss on fake data: 0.5694
# Generator loss: 4.5655
#
# -----Epoch: 4/75 Batch: 1100/64-----
# Discriminator loss on real data: 0.0738
# Discriminator loss on fake data: 0.5794
# Generator loss: 5.1103
#
# -----Epoch: 4/75 Batch: 1200/64-----
# Discriminator loss on real data: 0.0156
# Discriminator loss on fake data: 0.2820
# Generator loss: 3.7604
#
# -----Epoch: 4/75 Batch: 1300/64-----
# Discriminator loss on real data: 0.2857
# Discriminator loss on fake data: 0.0043
# Generator loss: 4.4887
#
# -----Epoch: 4/75 Batch: 1400/64-----
# Discriminator loss on real data: 0.1395
# Discriminator loss on fake data: 0.0001
# Generator loss: 11.7952
#
# -----Epoch: 4/75 Batch: 1500/64-----
# Discriminator loss on real data: 0.0051
# Discriminator loss on fake data: 0.2796
# Generator loss: 5.0761
#
# -----Epoch: 4/75 Batch: 1600/64-----
# Discriminator loss on real data: 0.0121
# Discriminator loss on fake data: 0.0069
# Generator loss: 6.6677
#
# -----Epoch: 4/75 Batch: 1700/64-----
# Discriminator loss on real data: 0.0591
# Discriminator loss on fake data: 0.0334
# Generator loss: 6.5473
#
# -----Epoch: 4/75 Batch: 1800/64-----
# Discriminator loss on real data: 0.0417
# Discriminator loss on fake data: 0.1606
# Generator loss: 6.6595
#
# -----Epoch: 4/75 Batch: 1900/64-----
# Discriminator loss on real data: 0.0278
# Discriminator loss on fake data: 0.0230
# Generator loss: 6.5409
#
# -----Epoch: 4/75 Batch: 2000/64-----
# Discriminator loss on real data: 0.0342
# Discriminator loss on fake data: 0.1979
# Generator loss: 4.1203
#
# -----Epoch: 4/75 Batch: 2100/64-----
# Discriminator loss on real data: 0.0119
# Discriminator loss on fake data: 0.0257
# Generator loss: 4.2338
# -----Epoch: 4/75 Batch: 2200/64-----
# Discriminator loss on real data: 0.0517
# Discriminator loss on fake data: 0.0526
# Generator loss: 6.8658
#
# -----Epoch: 4/75 Batch: 2300/64-----
# Discriminator loss on real data: 0.0134
# Discriminator loss on fake data: 0.2899
# Generator loss: 6.0664
#
# -----Epoch: 4/75 Batch: 2400/64-----
# Discriminator loss on real data: 0.0204
# Discriminator loss on fake data: 0.1596
# Generator loss: 5.5475
#
# -----Epoch: 4/75 Batch: 2500/64-----
# Discriminator loss on real data: 0.0821
# Discriminator loss on fake data: 0.0527
# Generator loss: 6.9436
#
# -----Epoch: 4/75 Batch: 2600/64-----
# Discriminator loss on real data: 0.0020
# Discriminator loss on fake data: 0.0244
# Generator loss: 8.0530
#
# -----Epoch: 4/75 Batch: 2700/64-----
# Discriminator loss on real data: 0.1266
# Discriminator loss on fake data: 0.0197
# Generator loss: 6.9789
#
# -----Epoch: 4/75 Batch: 2800/64-----
# Discriminator loss on real data: 0.0234
# Discriminator loss on fake data: 0.1374
# Generator loss: 6.4590
#
# -----Epoch: 4/75 Batch: 2900/64-----
# Discriminator loss on real data: 0.0812
# Discriminator loss on fake data: 0.0215
# Generator loss: 6.3130
#
# -----Epoch: 4/75 Batch: 3000/64-----
# Discriminator loss on real data: 0.0232
# Discriminator loss on fake data: 0.0299
# Generator loss: 6.6067
#
# -----Epoch: 4/75 Batch: 3100/64-----
# Discriminator loss on real data: 0.0175
# Discriminator loss on fake data: 0.8038
# Generator loss: 7.0416
#
# -----Epoch: 5/75 Batch: 0/64-----
# Discriminator loss on real data: 0.0135
# Discriminator loss on fake data: 0.0109
# Generator loss: 6.7276
#
# -----Epoch: 5/75 Batch: 100/64-----
# Discriminator loss on real data: 0.0050
# Discriminator loss on fake data: 0.0168
# Generator loss: 7.0786
#
# -----Epoch: 5/75 Batch: 200/64-----
# Discriminator loss on real data: 0.1384
# Discriminator loss on fake data: 0.0075
# Generator loss: 6.1603
#
# -----Epoch: 5/75 Batch: 300/64-----
# Discriminator loss on real data: 0.2312
# Discriminator loss on fake data: 0.0098
# Generator loss: 7.4744
#
# -----Epoch: 5/75 Batch: 400/64-----
# Discriminator loss on real data: 0.0184
# Discriminator loss on fake data: 0.0031
# Generator loss: 7.5773
#
# -----Epoch: 5/75 Batch: 500/64-----
# Discriminator loss on real data: 0.0311
# Discriminator loss on fake data: 0.0086
# Generator loss: 5.4384
#
# -----Epoch: 5/75 Batch: 600/64-----
# Discriminator loss on real data: 0.3826
# Discriminator loss on fake data: 0.0636
# Generator loss: 8.2215
#
# -----Epoch: 5/75 Batch: 700/64-----
# Discriminator loss on real data: 0.0120
# Discriminator loss on fake data: 0.2108
# Generator loss: 5.7953
#
# -----Epoch: 5/75 Batch: 800/64-----
# Discriminator loss on real data: 0.2307
# Discriminator loss on fake data: 0.0181
# Generator loss: 3.7494
#
# -----Epoch: 5/75 Batch: 900/64-----
# Discriminator loss on real data: 0.0115
# Discriminator loss on fake data: 0.2328
# Generator loss: 6.8725
#
# -----Epoch: 5/75 Batch: 1000/64-----
# Discriminator loss on real data: 0.0696
# Discriminator loss on fake data: 0.0763
# Generator loss: 4.2902
#
# -----Epoch: 5/75 Batch: 1100/64-----
# Discriminator loss on real data: 0.0158
# Discriminator loss on fake data: 0.0343
# Generator loss: 7.9068
#
# -----Epoch: 5/75 Batch: 1200/64-----
# Discriminator loss on real data: 0.0140
# Discriminator loss on fake data: 0.0124
# Generator loss: 5.7397
#
# -----Epoch: 5/75 Batch: 1300/64-----
# Discriminator loss on real data: 0.0033
# Discriminator loss on fake data: 0.7380
# Generator loss: 5.6967
#
# -----Epoch: 5/75 Batch: 1400/64-----
# Discriminator loss on real data: 0.0026
# Discriminator loss on fake data: 0.1628
# Generator loss: 4.5226
#
# -----Epoch: 5/75 Batch: 1500/64-----
# Discriminator loss on real data: 0.0132
# Discriminator loss on fake data: 0.0688
# Generator loss: 4.4024
#
# -----Epoch: 5/75 Batch: 1600/64-----
# Discriminator loss on real data: 0.0038
# Discriminator loss on fake data: 0.0546
# Generator loss: 7.4269
#
# -----Epoch: 5/75 Batch: 1700/64-----
# Discriminator loss on real data: 0.0007
# Discriminator loss on fake data: 0.1322
# Generator loss: 4.6783
#
# -----Epoch: 5/75 Batch: 1800/64-----
# Discriminator loss on real data: 0.1175
# Discriminator loss on fake data: 0.0026
# Generator loss: 4.0527
#
# -----Epoch: 5/75 Batch: 1900/64-----
# Discriminator loss on real data: 0.0142
# Discriminator loss on fake data: 0.0616
# Generator loss: 5.1646
#
# -----Epoch: 5/75 Batch: 2000/64-----
# Discriminator loss on real data: 0.0971
# Discriminator loss on fake data: 0.0012
# Generator loss: 8.1792
#
# -----Epoch: 5/75 Batch: 2100/64-----
# Discriminator loss on real data: 0.0014
# Discriminator loss on fake data: 0.2333
# Generator loss: 6.2305
#
# -----Epoch: 5/75 Batch: 2200/64-----
# Discriminator loss on real data: 0.0140
# Discriminator loss on fake data: 0.2816
# Generator loss: 3.5324
#
# -----Epoch: 5/75 Batch: 2300/64-----
# Discriminator loss on real data: 0.0105
# Discriminator loss on fake data: 0.1365
# Generator loss: 5.1223
#
# -----Epoch: 5/75 Batch: 2400/64-----
# Discriminator loss on real data: 0.0073
# Discriminator loss on fake data: 0.0526
# Generator loss: 4.8814
#
# -----Epoch: 5/75 Batch: 2500/64-----
# Discriminator loss on real data: 0.0125
# Discriminator loss on fake data: 0.0108
# Generator loss: 5.7839
#
# -----Epoch: 5/75 Batch: 2600/64-----
# Discriminator loss on real data: 0.0088
# Discriminator loss on fake data: 1.0545
# Generator loss: 5.0015
#
# -----Epoch: 5/75 Batch: 2700/64-----
# Discriminator loss on real data: 0.0122
# Discriminator loss on fake data: 0.0394
# Generator loss: 4.6378
#
# -----Epoch: 5/75 Batch: 2800/64-----
# Discriminator loss on real data: 0.1410
# Discriminator loss on fake data: 0.0076
# Generator loss: 8.5741
#
# -----Epoch: 5/75 Batch: 2900/64-----
# Discriminator loss on real data: 0.1058
# Discriminator loss on fake data: 0.0021
# Generator loss: 8.5383
#
# -----Epoch: 5/75 Batch: 3000/64-----
# Discriminator loss on real data: 0.0008
# Discriminator loss on fake data: 0.0676
# Generator loss: 5.0874
#
# -----Epoch: 5/75 Batch: 3100/64-----
# Discriminator loss on real data: 0.0072
# Discriminator loss on fake data: 0.0262
# Generator loss: 7.9667
#
# -----Epoch: 6/75 Batch: 0/64-----
# Discriminator loss on real data: 0.1489
# Discriminator loss on fake data: 0.0132
# Generator loss: 7.5988
#
# -----Epoch: 6/75 Batch: 100/64-----
# Discriminator loss on real data: 0.2327
# Discriminator loss on fake data: 0.0806
# Generator loss: 5.1502
#
# -----Epoch: 6/75 Batch: 200/64-----
# Discriminator loss on real data: 0.0521
# Discriminator loss on fake data: 0.1388
# Generator loss: 4.1986
#
# -----Epoch: 6/75 Batch: 300/64-----
# Discriminator loss on real data: 0.1750
# Discriminator loss on fake data: 0.0349
# Generator loss: 4.7872
#
# -----Epoch: 6/75 Batch: 400/64-----
# Discriminator loss on real data: 0.2822
# Discriminator loss on fake data: 0.0487
# Generator loss: 3.8785
#
# -----Epoch: 6/75 Batch: 500/64-----
# Discriminator loss on real data: 0.3498
# Discriminator loss on fake data: 0.0114
# Generator loss: 1.6518
#
# -----Epoch: 6/75 Batch: 600/64-----
# Discriminator loss on real data: 0.1608
# Discriminator loss on fake data: 0.0647
# Generator loss: 6.8041
#
# -----Epoch: 6/75 Batch: 700/64-----
# Discriminator loss on real data: 0.0131
# Discriminator loss on fake data: 0.0124
# Generator loss: 6.9277
#
# -----Epoch: 6/75 Batch: 800/64-----
# Discriminator loss on real data: 0.0036
# Discriminator loss on fake data: 0.2715
# Generator loss: 4.2759
#
# -----Epoch: 6/75 Batch: 900/64-----
# Discriminator loss on real data: 0.0574
# Discriminator loss on fake data: 0.0335
# Generator loss: 5.4007
#
# -----Epoch: 6/75 Batch: 1000/64-----
# Discriminator loss on real data: 0.1740
# Discriminator loss on fake data: 0.0399
# Generator loss: 5.0758
#
# -----Epoch: 6/75 Batch: 1100/64-----
# Discriminator loss on real data: 0.0545
# Discriminator loss on fake data: 0.0407
# Generator loss: 6.4609
#
# -----Epoch: 6/75 Batch: 1200/64-----
# Discriminator loss on real data: 0.0117
# Discriminator loss on fake data: 0.0299
# Generator loss: 9.0912
#
# -----Epoch: 6/75 Batch: 1300/64-----
# Discriminator loss on real data: 0.0066
# Discriminator loss on fake data: 0.0158
# Generator loss: 5.7697
#
# -----Epoch: 6/75 Batch: 1400/64-----
# Discriminator loss on real data: 0.0297
# Discriminator loss on fake data: 0.0211
# Generator loss: 7.4298
#
# -----Epoch: 6/75 Batch: 1500/64-----
# Discriminator loss on real data: 0.0455
# Discriminator loss on fake data: 0.0120
# Generator loss: 6.3311
#
# -----Epoch: 6/75 Batch: 1600/64-----
# Discriminator loss on real data: 0.0074
# Discriminator loss on fake data: 0.2238
# Generator loss: 5.8221
# -----Epoch: 6/75 Batch: 1700/64-----
# Discriminator loss on real data: 0.0044
# Discriminator loss on fake data: 0.6120
# Generator loss: 5.4960
#
# -----Epoch: 6/75 Batch: 1800/64-----
# Discriminator loss on real data: 0.0461
# Discriminator loss on fake data: 0.0104
# Generator loss: 9.8860
#
# -----Epoch: 6/75 Batch: 1900/64-----
# Discriminator loss on real data: 0.4883
# Discriminator loss on fake data: 0.0971
# Generator loss: 3.9285
#
# -----Epoch: 6/75 Batch: 2000/64-----
# Discriminator loss on real data: 0.5039
# Discriminator loss on fake data: 0.2919
# Generator loss: 2.8003
#
# -----Epoch: 6/75 Batch: 2100/64-----
# Discriminator loss on real data: 0.4704
# Discriminator loss on fake data: 0.0798
# Generator loss: 7.1080
#
# -----Epoch: 6/75 Batch: 2200/64-----
# Discriminator loss on real data: 0.0318
# Discriminator loss on fake data: 0.0807
# Generator loss: 5.9339
#
# -----Epoch: 6/75 Batch: 2300/64-----
# Discriminator loss on real data: 0.0179
# Discriminator loss on fake data: 0.3511
# Generator loss: 5.1464
#
# -----Epoch: 6/75 Batch: 2400/64-----
# Discriminator loss on real data: 0.0393
# Discriminator loss on fake data: 0.0459
# Generator loss: 4.7714
#
# -----Epoch: 6/75 Batch: 2500/64-----
# Discriminator loss on real data: 0.5002
# Discriminator loss on fake data: 0.0052
# Generator loss: 6.0823
#
# -----Epoch: 6/75 Batch: 2600/64-----
# Discriminator loss on real data: 0.0092
# Discriminator loss on fake data: 0.3994
# Generator loss: 5.0710
#
# -----Epoch: 6/75 Batch: 2700/64-----
# Discriminator loss on real data: 0.1380
# Discriminator loss on fake data: 0.0325
# Generator loss: 4.8287
#
# -----Epoch: 6/75 Batch: 2800/64-----
# Discriminator loss on real data: 0.1275
# Discriminator loss on fake data: 0.0103
# Generator loss: 6.5911
#
# -----Epoch: 6/75 Batch: 2900/64-----
# Discriminator loss on real data: 0.1352
# Discriminator loss on fake data: 0.0002
# Generator loss: 10.7263
#
# -----Epoch: 6/75 Batch: 3000/64-----
# Discriminator loss on real data: 0.0123
# Discriminator loss on fake data: 0.0527
# Generator loss: 5.6786
#
# -----Epoch: 6/75 Batch: 3100/64-----
# Discriminator loss on real data: 0.1087
# Discriminator loss on fake data: 0.0017
# Generator loss: 5.9723
#
# -----Epoch: 7/75 Batch: 0/64-----
# Discriminator loss on real data: 0.0023
# Discriminator loss on fake data: 0.0190
# Generator loss: 6.7162
#
# -----Epoch: 7/75 Batch: 100/64-----
# Discriminator loss on real data: 0.1561
# Discriminator loss on fake data: 0.0037
# Generator loss: 8.1388
#
# -----Epoch: 7/75 Batch: 200/64-----
# Discriminator loss on real data: 0.0167
# Discriminator loss on fake data: 0.0801
# Generator loss: 6.1625
#
# -----Epoch: 7/75 Batch: 300/64-----
# Discriminator loss on real data: 0.0635
# Discriminator loss on fake data: 0.0165
# Generator loss: 6.4734
#
# -----Epoch: 7/75 Batch: 400/64-----
# Discriminator loss on real data: 0.0680
# Discriminator loss on fake data: 0.0664
# Generator loss: 6.1367
#
# -----Epoch: 7/75 Batch: 500/64-----
# Discriminator loss on real data: 0.0471
# Discriminator loss on fake data: 0.0126
# Generator loss: 7.0221
#
# -----Epoch: 7/75 Batch: 600/64-----
# Discriminator loss on real data: 0.1338
# Discriminator loss on fake data: 0.0524
# Generator loss: 5.5067
#
# -----Epoch: 7/75 Batch: 700/64-----
# Discriminator loss on real data: 0.0583
# Discriminator loss on fake data: 0.0712
# Generator loss: 4.4121
#
# -----Epoch: 7/75 Batch: 800/64-----
# Discriminator loss on real data: 0.0154
# Discriminator loss on fake data: 0.0745
# Generator loss: 4.6433
#
# -----Epoch: 7/75 Batch: 900/64-----
# Discriminator loss on real data: 0.0236
# Discriminator loss on fake data: 0.0795
# Generator loss: 5.5422
#
# -----Epoch: 7/75 Batch: 1000/64-----
# Discriminator loss on real data: 0.0001
# Discriminator loss on fake data: 0.1019
# Generator loss: 5.9628
#
# -----Epoch: 7/75 Batch: 1100/64-----
# Discriminator loss on real data: 0.4554
# Discriminator loss on fake data: 0.0149
# Generator loss: 4.2279
#
# -----Epoch: 7/75 Batch: 1200/64-----
# Discriminator loss on real data: 0.5270
# Discriminator loss on fake data: 0.0147
# Generator loss: 5.0102
#
# -----Epoch: 7/75 Batch: 1300/64-----
# Discriminator loss on real data: 0.1275
# Discriminator loss on fake data: 0.0445
# Generator loss: 3.5394
#
# -----Epoch: 7/75 Batch: 1400/64-----
# Discriminator loss on real data: 0.0234
# Discriminator loss on fake data: 0.0747
# Generator loss: 5.5271
#
# -----Epoch: 7/75 Batch: 1500/64-----
# Discriminator loss on real data: 0.0039
# Discriminator loss on fake data: 0.3514
# Generator loss: 6.8923
#
# -----Epoch: 7/75 Batch: 1600/64-----
# Discriminator loss on real data: 0.0040
# Discriminator loss on fake data: 0.1729
# Generator loss: 5.0931
#
# -----Epoch: 7/75 Batch: 1700/64-----
# Discriminator loss on real data: 0.0086
# Discriminator loss on fake data: 0.0879
# Generator loss: 4.0363
#
# -----Epoch: 7/75 Batch: 1800/64-----
# Discriminator loss on real data: 0.0105
# Discriminator loss on fake data: 0.8230
# Generator loss: 5.0301
#
# -----Epoch: 7/75 Batch: 1900/64-----
# Discriminator loss on real data: 0.0022
# Discriminator loss on fake data: 0.0954
# Generator loss: 4.9420
#
# -----Epoch: 7/75 Batch: 2000/64-----
# Discriminator loss on real data: 0.0383
# Discriminator loss on fake data: 0.0478
# Generator loss: 8.6286
#
# -----Epoch: 7/75 Batch: 2100/64-----
# Discriminator loss on real data: 0.0676
# Discriminator loss on fake data: 0.0041
# Generator loss: 8.6107
#
# -----Epoch: 7/75 Batch: 2200/64-----
# Discriminator loss on real data: 0.1938
# Discriminator loss on fake data: 0.0420
# Generator loss: 3.8731
#
# -----Epoch: 7/75 Batch: 2300/64-----
# Discriminator loss on real data: 0.6094
# Discriminator loss on fake data: 0.0045
# Generator loss: 6.4900
#
# -----Epoch: 7/75 Batch: 2400/64-----
# Discriminator loss on real data: 0.0170
# Discriminator loss on fake data: 0.3407
# Generator loss: 3.1849
#
# -----Epoch: 7/75 Batch: 2500/64-----
# Discriminator loss on real data: 0.0567
# Discriminator loss on fake data: 0.0525
# Generator loss: 5.8358
#
# -----Epoch: 7/75 Batch: 2600/64-----
# Discriminator loss on real data: 0.3627
# Discriminator loss on fake data: 0.0079
# Generator loss: 4.8870
#
# -----Epoch: 7/75 Batch: 2700/64-----
# Discriminator loss on real data: 0.0115
# Discriminator loss on fake data: 0.0842
# Generator loss: 7.1443
#
# -----Epoch: 7/75 Batch: 2800/64-----
# Discriminator loss on real data: 0.0030
# Discriminator loss on fake data: 0.1383
# Generator loss: 5.8384
#
# -----Epoch: 7/75 Batch: 2900/64-----
# Discriminator loss on real data: 0.0022
# Discriminator loss on fake data: 0.0307
# Generator loss: 6.3903
#
# -----Epoch: 7/75 Batch: 3000/64-----
# Discriminator loss on real data: 0.0195
# Discriminator loss on fake data: 0.0320
# Generator loss: 7.3004
#
# -----Epoch: 7/75 Batch: 3100/64-----
# Discriminator loss on real data: 0.0360
# Discriminator loss on fake data: 0.0444
# Generator loss: 7.8523
#
# -----Epoch: 8/75 Batch: 0/64-----
# Discriminator loss on real data: 0.0375
# Discriminator loss on fake data: 0.0550
# Generator loss: 4.0872
#
# -----Epoch: 8/75 Batch: 100/64-----
# Discriminator loss on real data: 0.0116
# Discriminator loss on fake data: 0.0637
# Generator loss: 4.1896
#
# -----Epoch: 8/75 Batch: 200/64-----
# Discriminator loss on real data: 0.0009
# Discriminator loss on fake data: 0.0775
# Generator loss: 5.6770
#
# -----Epoch: 8/75 Batch: 300/64-----
# Discriminator loss on real data: 0.0337
# Discriminator loss on fake data: 0.0191
# Generator loss: 7.5557
#
# -----Epoch: 8/75 Batch: 400/64-----
# Discriminator loss on real data: 0.0024
# Discriminator loss on fake data: 0.0905
# Generator loss: 3.4023
#
# -----Epoch: 8/75 Batch: 500/64-----
# Discriminator loss on real data: 0.1983
# Discriminator loss on fake data: 0.0040
# Generator loss: 6.7118
#
# -----Epoch: 8/75 Batch: 600/64-----
# Discriminator loss on real data: 0.0014
# Discriminator loss on fake data: 0.1533
# Generator loss: 3.4263
#
# -----Epoch: 8/75 Batch: 700/64-----
# Discriminator loss on real data: 0.2238
# Discriminator loss on fake data: 0.0076
# Generator loss: 4.9695
#
# -----Epoch: 8/75 Batch: 800/64-----
# Discriminator loss on real data: 0.0733
# Discriminator loss on fake data: 0.0078
# Generator loss: 8.5696
#
# -----Epoch: 8/75 Batch: 900/64-----
# Discriminator loss on real data: 0.0146
# Discriminator loss on fake data: 0.0241
# Generator loss: 5.7886
#
# -----Epoch: 8/75 Batch: 1000/64-----
# Discriminator loss on real data: 0.1079
# Discriminator loss on fake data: 0.0165
# Generator loss: 6.5031
#
# -----Epoch: 8/75 Batch: 1100/64-----
# Discriminator loss on real data: 0.1146
# Discriminator loss on fake data: 0.0561
# Generator loss: 5.3642
# -----Epoch: 8/75 Batch: 1200/64-----
# Discriminator loss on real data: 0.2049
# Discriminator loss on fake data: 0.0068
# Generator loss: 8.1395
#
# -----Epoch: 8/75 Batch: 1300/64-----
# Discriminator loss on real data: 0.0575
# Discriminator loss on fake data: 0.0154
# Generator loss: 5.4784
#
# -----Epoch: 8/75 Batch: 1400/64-----
# Discriminator loss on real data: 0.1018
# Discriminator loss on fake data: 0.0618
# Generator loss: 3.8231
#
# -----Epoch: 8/75 Batch: 1500/64-----
# Discriminator loss on real data: 0.0288
# Discriminator loss on fake data: 0.0557
# Generator loss: 2.4431
#
# -----Epoch: 8/75 Batch: 1600/64-----
# Discriminator loss on real data: 0.0626
# Discriminator loss on fake data: 0.0553
# Generator loss: 5.7421
#
# -----Epoch: 8/75 Batch: 1700/64-----
# Discriminator loss on real data: 0.0169
# Discriminator loss on fake data: 0.0381
# Generator loss: 5.4663
#
# -----Epoch: 8/75 Batch: 1800/64-----
# Discriminator loss on real data: 0.0004
# Discriminator loss on fake data: 1.2229
# Generator loss: 9.2128
#
# -----Epoch: 8/75 Batch: 1900/64-----
# Discriminator loss on real data: 0.0399
# Discriminator loss on fake data: 0.1377
# Generator loss: 5.5370
#
# -----Epoch: 8/75 Batch: 2000/64-----
# Discriminator loss on real data: 0.2146
# Discriminator loss on fake data: 0.0761
# Generator loss: 3.0466
#
# -----Epoch: 8/75 Batch: 2100/64-----
# Discriminator loss on real data: 0.0064
# Discriminator loss on fake data: 0.0472
# Generator loss: 6.0573
#
# -----Epoch: 8/75 Batch: 2200/64-----
# Discriminator loss on real data: 0.0079
# Discriminator loss on fake data: 0.0196
# Generator loss: 2.3702
#
# -----Epoch: 8/75 Batch: 2300/64-----
# Discriminator loss on real data: 0.2417
# Discriminator loss on fake data: 0.0192
# Generator loss: 6.0358
#
# -----Epoch: 8/75 Batch: 2400/64-----
# Discriminator loss on real data: 0.0099
# Discriminator loss on fake data: 0.0165
# Generator loss: 6.4148
#
# -----Epoch: 8/75 Batch: 2500/64-----
# Discriminator loss on real data: 0.0106
# Discriminator loss on fake data: 0.0976
# Generator loss: 5.7322
#
# -----Epoch: 8/75 Batch: 2600/64-----
# Discriminator loss on real data: 0.0085
# Discriminator loss on fake data: 0.0759
# Generator loss: 6.1404
#
# -----Epoch: 8/75 Batch: 2700/64-----
# Discriminator loss on real data: 0.0437
# Discriminator loss on fake data: 0.1372
# Generator loss: 5.3894
#
# -----Epoch: 8/75 Batch: 2800/64-----
# Discriminator loss on real data: 0.0307
# Discriminator loss on fake data: 0.0545
# Generator loss: 4.4972
#
# -----Epoch: 8/75 Batch: 2900/64-----
# Discriminator loss on real data: 0.0053
# Discriminator loss on fake data: 0.0851
# Generator loss: 3.6439
#
# -----Epoch: 8/75 Batch: 3000/64-----
# Discriminator loss on real data: 0.0111
# Discriminator loss on fake data: 0.0588
# Generator loss: 6.5931
#
# -----Epoch: 8/75 Batch: 3100/64-----
# Discriminator loss on real data: 0.0182
# Discriminator loss on fake data: 0.1410
# Generator loss: 2.9877
#
# -----Epoch: 9/75 Batch: 0/64-----
# Discriminator loss on real data: 0.0613
# Discriminator loss on fake data: 0.5516
# Generator loss: 3.3519
#
# -----Epoch: 9/75 Batch: 100/64-----
# Discriminator loss on real data: 0.0240
# Discriminator loss on fake data: 0.1159
# Generator loss: 4.0392
#
# -----Epoch: 9/75 Batch: 200/64-----
# Discriminator loss on real data: 0.0211
# Discriminator loss on fake data: 0.0657
# Generator loss: 7.5741
#
# -----Epoch: 9/75 Batch: 300/64-----
# Discriminator loss on real data: 0.0033
# Discriminator loss on fake data: 0.0415
# Generator loss: 4.5680
#
# -----Epoch: 9/75 Batch: 400/64-----
# Discriminator loss on real data: 0.0248
# Discriminator loss on fake data: 0.0036
# Generator loss: 8.2662
#
# -----Epoch: 9/75 Batch: 500/64-----
# Discriminator loss on real data: 0.1298
# Discriminator loss on fake data: 0.0177
# Generator loss: 4.6870
#
# -----Epoch: 9/75 Batch: 600/64-----
# Discriminator loss on real data: 0.0627
# Discriminator loss on fake data: 0.1090
# Generator loss: 5.9973
#
# -----Epoch: 9/75 Batch: 700/64-----
# Discriminator loss on real data: 0.0038
# Discriminator loss on fake data: 0.2428
# Generator loss: 4.0867
#
# -----Epoch: 9/75 Batch: 800/64-----
# Discriminator loss on real data: 0.0692
# Discriminator loss on fake data: 0.0315
# Generator loss: 6.0348
#
# -----Epoch: 9/75 Batch: 900/64-----
# Discriminator loss on real data: 0.1180
# Discriminator loss on fake data: 0.0014
# Generator loss: 8.8698
#
# -----Epoch: 9/75 Batch: 1000/64-----
# Discriminator loss on real data: 0.0572
# Discriminator loss on fake data: 0.0668
# Generator loss: 6.1898
#
# -----Epoch: 9/75 Batch: 1100/64-----
# Discriminator loss on real data: 0.0433
# Discriminator loss on fake data: 0.0341
# Generator loss: 5.4281
#
# -----Epoch: 9/75 Batch: 1200/64-----
# Discriminator loss on real data: 0.2363
# Discriminator loss on fake data: 0.0391
# Generator loss: 2.2141
#
# -----Epoch: 9/75 Batch: 1300/64-----
# Discriminator loss on real data: 0.0029
# Discriminator loss on fake data: 0.1638
# Generator loss: 3.6391
#
# -----Epoch: 9/75 Batch: 1400/64-----
# Discriminator loss on real data: 0.0320
# Discriminator loss on fake data: 0.0310
# Generator loss: 5.2581
#
# -----Epoch: 9/75 Batch: 1500/64-----
# Discriminator loss on real data: 0.0060
# Discriminator loss on fake data: 0.0201
# Generator loss: 6.0640
#
# -----Epoch: 9/75 Batch: 1600/64-----
# Discriminator loss on real data: 0.0032
# Discriminator loss on fake data: 0.9115
# Generator loss: 8.1031
#
# -----Epoch: 9/75 Batch: 1700/64-----
# Discriminator loss on real data: 0.1214
# Discriminator loss on fake data: 0.7664
# Generator loss: 4.5573
#
# -----Epoch: 9/75 Batch: 1800/64-----
# Discriminator loss on real data: 0.2561
# Discriminator loss on fake data: 0.0090
# Generator loss: 6.3434
#
# -----Epoch: 9/75 Batch: 1900/64-----
# Discriminator loss on real data: 0.0004
# Discriminator loss on fake data: 1.3689
# Generator loss: 4.0441
#
# -----Epoch: 9/75 Batch: 2000/64-----
# Discriminator loss on real data: 0.4802
# Discriminator loss on fake data: 0.0312
# Generator loss: 5.5273
#
# -----Epoch: 9/75 Batch: 2100/64-----
# Discriminator loss on real data: 0.1013
# Discriminator loss on fake data: 0.0428
# Generator loss: 5.1923
#
# -----Epoch: 9/75 Batch: 2200/64-----
# Discriminator loss on real data: 0.0013
# Discriminator loss on fake data: 0.2768
# Generator loss: 3.6480
#
# -----Epoch: 9/75 Batch: 2300/64-----
# Discriminator loss on real data: 0.0171
# Discriminator loss on fake data: 0.0141
# Generator loss: 6.9908
#
# -----Epoch: 9/75 Batch: 2400/64-----
# Discriminator loss on real data: 0.2083
# Discriminator loss on fake data: 0.0016
# Generator loss: 9.2785
#
# -----Epoch: 9/75 Batch: 2500/64-----
# Discriminator loss on real data: 0.3833
# Discriminator loss on fake data: 0.0005
# Generator loss: 11.2590
#
# -----Epoch: 9/75 Batch: 2600/64-----
# Discriminator loss on real data: 0.1311
# Discriminator loss on fake data: 0.0461
# Generator loss: 4.1983
#
# -----Epoch: 9/75 Batch: 2700/64-----
# Discriminator loss on real data: 0.0194
# Discriminator loss on fake data: 0.0666
# Generator loss: 7.1740
#
# -----Epoch: 9/75 Batch: 2800/64-----
# Discriminator loss on real data: 0.0698
# Discriminator loss on fake data: 0.0372
# Generator loss: 6.7446
#
# -----Epoch: 9/75 Batch: 2900/64-----
# Discriminator loss on real data: 0.0148
# Discriminator loss on fake data: 0.3282
# Generator loss: 3.8186
#
# -----Epoch: 9/75 Batch: 3000/64-----
# Discriminator loss on real data: 0.0271
# Discriminator loss on fake data: 0.0413
# Generator loss: 4.5024
#
# -----Epoch: 9/75 Batch: 3100/64-----
# Discriminator loss on real data: 0.4751
# Discriminator loss on fake data: 0.0010
# Generator loss: 8.4128
#
# -----Epoch: 10/75 Batch: 0/64-----
# Discriminator loss on real data: 0.0155
# Discriminator loss on fake data: 0.1862
# Generator loss: 5.9897
#
# -----Epoch: 10/75 Batch: 100/64-----
# Discriminator loss on real data: 0.0160
# Discriminator loss on fake data: 0.0285
# Generator loss: 4.8771
#
# -----Epoch: 10/75 Batch: 200/64-----
# Discriminator loss on real data: 0.2514
# Discriminator loss on fake data: 0.0016
# Generator loss: 7.9407
#
# -----Epoch: 10/75 Batch: 300/64-----
# Discriminator loss on real data: 0.0025
# Discriminator loss on fake data: 0.3440
# Generator loss: 4.4418
#
# -----Epoch: 10/75 Batch: 400/64-----
# Discriminator loss on real data: 0.1368
# Discriminator loss on fake data: 0.0479
# Generator loss: 6.0678
#
# -----Epoch: 10/75 Batch: 500/64-----
# Discriminator loss on real data: 0.2297
# Discriminator loss on fake data: 0.0482
# Generator loss: 5.5006
#
# -----Epoch: 10/75 Batch: 600/64-----
# Discriminator loss on real data: 0.2849
# Discriminator loss on fake data: 0.1406
# Generator loss: 6.0321
# -----Epoch: 10/75 Batch: 700/64-----
# Discriminator loss on real data: 0.0385
# Discriminator loss on fake data: 0.0871
# Generator loss: 5.6028
#
# -----Epoch: 10/75 Batch: 800/64-----
# Discriminator loss on real data: 0.0102
# Discriminator loss on fake data: 0.0042
# Generator loss: 8.8337
#
# -----Epoch: 10/75 Batch: 900/64-----
# Discriminator loss on real data: 0.1619
# Discriminator loss on fake data: 0.0249
# Generator loss: 4.7284
#
# -----Epoch: 10/75 Batch: 1000/64-----
# Discriminator loss on real data: 0.2961
# Discriminator loss on fake data: 0.0015
# Generator loss: 7.3515
#
# -----Epoch: 10/75 Batch: 1100/64-----
# Discriminator loss on real data: 0.4969
# Discriminator loss on fake data: 0.0011
# Generator loss: 6.1296
#
# -----Epoch: 10/75 Batch: 1200/64-----
# Discriminator loss on real data: 0.0333
# Discriminator loss on fake data: 0.0743
# Generator loss: 5.8125
#
# -----Epoch: 10/75 Batch: 1300/64-----
# Discriminator loss on real data: 0.0180
# Discriminator loss on fake data: 0.0558
# Generator loss: 7.2311
#
# -----Epoch: 10/75 Batch: 1400/64-----
# Discriminator loss on real data: 0.5959
# Discriminator loss on fake data: 0.0099
# Generator loss: 8.4625
#
# -----Epoch: 10/75 Batch: 1500/64-----
# Discriminator loss on real data: 0.1048
# Discriminator loss on fake data: 0.0296
# Generator loss: 5.1819
#
# -----Epoch: 10/75 Batch: 1600/64-----
# Discriminator loss on real data: 0.0089
# Discriminator loss on fake data: 0.0842
# Generator loss: 4.9664
#
# -----Epoch: 10/75 Batch: 1700/64-----
# Discriminator loss on real data: 1.2753
# Discriminator loss on fake data: 0.0032
# Generator loss: 3.8908
#
# -----Epoch: 10/75 Batch: 1800/64-----
# Discriminator loss on real data: 0.0592
# Discriminator loss on fake data: 0.0237
# Generator loss: 6.1441
#
# -----Epoch: 10/75 Batch: 1900/64-----
# Discriminator loss on real data: 0.1753
# Discriminator loss on fake data: 0.0039
# Generator loss: 9.1522
#
# -----Epoch: 10/75 Batch: 2000/64-----
# Discriminator loss on real data: 0.0002
# Discriminator loss on fake data: 0.3931
# Generator loss: 4.8279
#
# -----Epoch: 10/75 Batch: 2100/64-----
# Discriminator loss on real data: 0.1867
# Discriminator loss on fake data: 0.0036
# Generator loss: 7.3347
#
# -----Epoch: 10/75 Batch: 2200/64-----
# Discriminator loss on real data: 0.0022
# Discriminator loss on fake data: 0.0307
# Generator loss: 8.8266
#
# -----Epoch: 10/75 Batch: 2300/64-----
# Discriminator loss on real data: 0.0289
# Discriminator loss on fake data: 0.0122
# Generator loss: 5.7956
#
# -----Epoch: 10/75 Batch: 2400/64-----
# Discriminator loss on real data: 0.0308
# Discriminator loss on fake data: 0.2785
# Generator loss: 3.0713
#
# -----Epoch: 10/75 Batch: 2500/64-----
# Discriminator loss on real data: 0.3872
# Discriminator loss on fake data: 0.1111
# Generator loss: 3.6357
#
# -----Epoch: 10/75 Batch: 2600/64-----
# Discriminator loss on real data: 0.1402
# Discriminator loss on fake data: 0.0217
# Generator loss: 4.5868
#
# -----Epoch: 10/75 Batch: 2700/64-----
# Discriminator loss on real data: 0.0096
# Discriminator loss on fake data: 0.0264
# Generator loss: 5.5267
#
# -----Epoch: 10/75 Batch: 2800/64-----
# Discriminator loss on real data: 0.0013
# Discriminator loss on fake data: 0.2169
# Generator loss: 3.9960
#
# -----Epoch: 10/75 Batch: 2900/64-----
# Discriminator loss on real data: 0.0600
# Discriminator loss on fake data: 0.0070
# Generator loss: 7.1339
#
# -----Epoch: 10/75 Batch: 3000/64-----
# Discriminator loss on real data: 0.0153
# Discriminator loss on fake data: 0.0968
# Generator loss: 5.5948
#
# -----Epoch: 10/75 Batch: 3100/64-----
# Discriminator loss on real data: 0.9245
# Discriminator loss on fake data: 0.0041
# Generator loss: 4.5180
#
# -----Epoch: 11/75 Batch: 0/64-----
# Discriminator loss on real data: 0.0016
# Discriminator loss on fake data: 0.1699
# Generator loss: 3.4506
#
# -----Epoch: 11/75 Batch: 100/64-----
# Discriminator loss on real data: 0.0040
# Discriminator loss on fake data: 0.1758
# Generator loss: 5.0443
#
# -----Epoch: 11/75 Batch: 200/64-----
# Discriminator loss on real data: 0.0022
# Discriminator loss on fake data: 0.3007
# Generator loss: 4.1786
#
# -----Epoch: 11/75 Batch: 300/64-----
# Discriminator loss on real data: 0.0241
# Discriminator loss on fake data: 0.1819
# Generator loss: 5.4647
#
# -----Epoch: 11/75 Batch: 400/64-----
# Discriminator loss on real data: 0.0003
# Discriminator loss on fake data: 0.0519
# Generator loss: 5.9293
#
# -----Epoch: 11/75 Batch: 500/64-----
# Discriminator loss on real data: 0.0139
# Discriminator loss on fake data: 0.0869
# Generator loss: 5.4332
#
# -----Epoch: 11/75 Batch: 600/64-----
# Discriminator loss on real data: 0.0127
# Discriminator loss on fake data: 0.0396
# Generator loss: 5.8410
#
# -----Epoch: 11/75 Batch: 700/64-----
# Discriminator loss on real data: 0.1042
# Discriminator loss on fake data: 0.0099
# Generator loss: 6.1942
#
# -----Epoch: 11/75 Batch: 800/64-----
# Discriminator loss on real data: 0.2551
# Discriminator loss on fake data: 0.0002
# Generator loss: 11.7236
#
# -----Epoch: 11/75 Batch: 900/64-----
# Discriminator loss on real data: 0.1028
# Discriminator loss on fake data: 0.0356
# Generator loss: 5.8542
#
# -----Epoch: 11/75 Batch: 1000/64-----
# Discriminator loss on real data: 0.0538
# Discriminator loss on fake data: 0.0462
# Generator loss: 4.5024
#
# -----Epoch: 11/75 Batch: 1100/64-----
# Discriminator loss on real data: 0.1966
# Discriminator loss on fake data: 0.1380
# Generator loss: 3.6124
#
# -----Epoch: 11/75 Batch: 1200/64-----
# Discriminator loss on real data: 0.4899
# Discriminator loss on fake data: 0.0053
# Generator loss: 5.5162
#
# -----Epoch: 11/75 Batch: 1300/64-----
# Discriminator loss on real data: 0.2168
# Discriminator loss on fake data: 0.0013
# Generator loss: 6.8667
#
# -----Epoch: 11/75 Batch: 1400/64-----
# Discriminator loss on real data: 0.0007
# Discriminator loss on fake data: 0.2617
# Generator loss: 3.3497
#
# -----Epoch: 11/75 Batch: 1500/64-----
# Discriminator loss on real data: 0.0350
# Discriminator loss on fake data: 0.1873
# Generator loss: 2.8832
#
# -----Epoch: 11/75 Batch: 1600/64-----
# Discriminator loss on real data: 0.0665
# Discriminator loss on fake data: 0.0382
# Generator loss: 5.5001
#
# -----Epoch: 11/75 Batch: 1700/64-----
# Discriminator loss on real data: 0.0340
# Discriminator loss on fake data: 0.2137
# Generator loss: 6.1463
#
# -----Epoch: 11/75 Batch: 1800/64-----
# Discriminator loss on real data: 0.1526
# Discriminator loss on fake data: 0.0510
# Generator loss: 5.5291
#
# -----Epoch: 11/75 Batch: 1900/64-----
# Discriminator loss on real data: 0.0859
# Discriminator loss on fake data: 0.0017
# Generator loss: 7.4951
#
# -----Epoch: 11/75 Batch: 2000/64-----
# Discriminator loss on real data: 0.0849
# ...
# Discriminator loss on real data: 0.0017
# Discriminator loss on fake data: 0.0284
# Generator loss: 6.4764
#
# -----Epoch: 25/75 Batch: 1000/64-----
# Discriminator loss on real data: 0.0058
# Discriminator loss on fake data: 0.0052
# Generator loss: 8.3629
#
# -----Epoch: 25/75 Batch: 1100/64-----
# Discriminator loss on real data: 0.0001
# Discriminator loss on fake data: 0.0967
# Generator loss: 3.6985
#
# -----Epoch: 25/75 Batch: 1200/64-----
# Discriminator loss on real data: 0.0118
# Discriminator loss on fake data: 0.0041
# Generator loss: 8.2297
#
# -----Epoch: 25/75 Batch: 1300/64-----
# Discriminator loss on real data: 0.1376
# Discriminator loss on fake data: 0.0173
# Generator loss: 4.9039
#
# -----Epoch: 25/75 Batch: 1400/64-----
# Discriminator loss on real data: 0.0760
# Discriminator loss on fake data: 0.0040
# Generator loss: 6.1666
#
# -----Epoch: 25/75 Batch: 1500/64-----
# Discriminator loss on real data: 0.0000
# Discriminator loss on fake data: 1.2575
# Generator loss: 6.4720
#
# -----Epoch: 25/75 Batch: 1600/64-----
# Discriminator loss on real data: 0.2797
# Discriminator loss on fake data: 0.0003
# Generator loss: 9.9465
#
# -----Epoch: 25/75 Batch: 1700/64-----
# Discriminator loss on real data: 0.0177
# Discriminator loss on fake data: 0.0155
# Generator loss: 7.3880
#
# -----Epoch: 25/75 Batch: 1800/64-----
# Discriminator loss on real data: 0.0000
# Discriminator loss on fake data: 0.2119
# Generator loss: 3.9814
#
# -----Epoch: 25/75 Batch: 1900/64-----
# Discriminator loss on real data: 0.0035
# Discriminator loss on fake data: 0.0120
# Generator loss: 6.9220
#
# -----Epoch: 25/75 Batch: 2000/64-----
# Discriminator loss on real data: 0.0157
# Discriminator loss on fake data: 0.0315
# Generator loss: 6.2034
#
# -----Epoch: 25/75 Batch: 2100/64-----
# Discriminator loss on real data: 0.0375
# Discriminator loss on fake data: 0.0060
# Generator loss: 8.0940
#
# -----Epoch: 25/75 Batch: 2200/64-----
# Discriminator loss on real data: 0.0001
# Discriminator loss on fake data: 0.0114
# Generator loss: 6.5480
#
# -----Epoch: 25/75 Batch: 2300/64-----
# Discriminator loss on real data: 0.9538
# Discriminator loss on fake data: 0.0007
# Generator loss: 9.0925
#
# -----Epoch: 25/75 Batch: 2400/64-----
# Discriminator loss on real data: 0.5962
# Discriminator loss on fake data: 0.0002
# Generator loss: 9.6022
#
# -----Epoch: 25/75 Batch: 2500/64-----
# Discriminator loss on real data: 0.0082
# Discriminator loss on fake data: 0.0077
# Generator loss: 7.3865
#
# -----Epoch: 25/75 Batch: 2600/64-----
# Discriminator loss on real data: 0.0004
# Discriminator loss on fake data: 0.0050
# Generator loss: 7.0609
#
# -----Epoch: 25/75 Batch: 2700/64-----
# Discriminator loss on real data: 0.0772
# Discriminator loss on fake data: 0.0084
# Generator loss: 7.7642
#
# -----Epoch: 25/75 Batch: 2800/64-----
# Discriminator loss on real data: 0.0012
# Discriminator loss on fake data: 0.1132
# Generator loss: 5.4361
#
# -----Epoch: 25/75 Batch: 2900/64-----
# Discriminator loss on real data: 0.0097
# Discriminator loss on fake data: 0.0060
# Generator loss: 7.5447
#
# -----Epoch: 25/75 Batch: 3000/64-----
# Discriminator loss on real data: 0.0015
# Discriminator loss on fake data: 0.0010
# Generator loss: 8.6624
#
# -----Epoch: 25/75 Batch: 3100/64-----
# Discriminator loss on real data: 0.0066
# Discriminator loss on fake data: 0.0037
# Generator loss: 6.2553
#
# -----Epoch: 26/75 Batch: 0/64-----
# Discriminator loss on real data: 0.0008
# Discriminator loss on fake data: 0.0101
# Generator loss: 7.2065
#
# -----Epoch: 26/75 Batch: 100/64-----
# Discriminator loss on real data: 0.0110
# Discriminator loss on fake data: 0.0001
# Generator loss: 12.2643
#
# -----Epoch: 26/75 Batch: 200/64-----
# Discriminator loss on real data: 0.0071
# Discriminator loss on fake data: 0.0080
# Generator loss: 8.5847
#
# -----Epoch: 26/75 Batch: 300/64-----
# Discriminator loss on real data: 0.0018
# Discriminator loss on fake data: 0.0087
# Generator loss: 7.4121
#
# -----Epoch: 26/75 Batch: 400/64-----
# Discriminator loss on real data: 0.0907
# Discriminator loss on fake data: 0.0004
# Generator loss: 10.1688
#
# -----Epoch: 26/75 Batch: 500/64-----
# Discriminator loss on real data: 0.0002
# Discriminator loss on fake data: 0.2205
# Generator loss: 8.4174
#
# -----Epoch: 26/75 Batch: 600/64-----
# Discriminator loss on real data: 0.1787
# Discriminator loss on fake data: 0.0018
# Generator loss: 6.9615
#
# -----Epoch: 26/75 Batch: 700/64-----
# Discriminator loss on real data: 0.0093
# Discriminator loss on fake data: 0.0004
# Generator loss: 11.6637
#
# -----Epoch: 26/75 Batch: 800/64-----
# Discriminator loss on real data: 0.0012
# Discriminator loss on fake data: 0.0164
# Generator loss: 7.3906
#
# -----Epoch: 26/75 Batch: 900/64-----
# Discriminator loss on real data: 0.0001
# Discriminator loss on fake data: 0.1259
# Generator loss: 6.2281
#
# -----Epoch: 26/75 Batch: 1000/64-----
# Discriminator loss on real data: 0.0588
# Discriminator loss on fake data: 0.0005
# Generator loss: 8.8498
#
# -----Epoch: 26/75 Batch: 1100/64-----
# Discriminator loss on real data: 0.0001
# Discriminator loss on fake data: 0.0020
# Generator loss: 8.2234
#
# -----Epoch: 26/75 Batch: 1200/64-----
# Discriminator loss on real data: 0.0180
# Discriminator loss on fake data: 0.0203
# Generator loss: 9.2957
#
# -----Epoch: 26/75 Batch: 1300/64-----
# Discriminator loss on real data: 0.0059
# Discriminator loss on fake data: 0.0023
# Generator loss: 8.2998
#
# -----Epoch: 26/75 Batch: 1400/64-----
# Discriminator loss on real data: 0.0005
# Discriminator loss on fake data: 0.0110
# Generator loss: 6.7335
#
# -----Epoch: 26/75 Batch: 1500/64-----
# Discriminator loss on real data: 0.0314
# Discriminator loss on fake data: 0.0026
# Generator loss: 6.9365
#
# -----Epoch: 26/75 Batch: 1600/64-----
# Discriminator loss on real data: 0.0002
# Discriminator loss on fake data: 0.0198
# Generator loss: 4.2288
# -----Epoch: 26/75 Batch: 1700/64-----
# Discriminator loss on real data: 0.0026
# Discriminator loss on fake data: 0.1663
# Generator loss: 7.0262
#
# -----Epoch: 26/75 Batch: 1800/64-----
# Discriminator loss on real data: 0.0018
# Discriminator loss on fake data: 0.0049
# Generator loss: 7.2406
#
# -----Epoch: 26/75 Batch: 1900/64-----
# Discriminator loss on real data: 0.0007
# Discriminator loss on fake data: 0.0389
# Generator loss: 6.9393
#
# -----Epoch: 26/75 Batch: 2000/64-----
# Discriminator loss on real data: 0.1718
# Discriminator loss on fake data: 0.0085
# Generator loss: 7.4035
#
# -----Epoch: 26/75 Batch: 2100/64-----
# Discriminator loss on real data: 0.2015
# Discriminator loss on fake data: 0.0016
# Generator loss: 6.1032
#
# -----Epoch: 26/75 Batch: 2200/64-----
# Discriminator loss on real data: 0.0011
# Discriminator loss on fake data: 0.0005
# Generator loss: 12.2238
#
# -----Epoch: 26/75 Batch: 2300/64-----
# Discriminator loss on real data: 0.0525
# Discriminator loss on fake data: 0.0047
# Generator loss: 8.4923
#
# -----Epoch: 26/75 Batch: 2400/64-----
# Discriminator loss on real data: 0.0430
# Discriminator loss on fake data: 0.0005
# Generator loss: 10.4134
#
# -----Epoch: 26/75 Batch: 2500/64-----
# Discriminator loss on real data: 0.2884
# Discriminator loss on fake data: 0.0153
# Generator loss: 3.8199
#
# -----Epoch: 26/75 Batch: 2600/64-----
# Discriminator loss on real data: 0.0001
# Discriminator loss on fake data: 0.0125
# Generator loss: 9.7452
#
# -----Epoch: 26/75 Batch: 2700/64-----
# Discriminator loss on real data: 0.0437
# Discriminator loss on fake data: 0.0002
# Generator loss: 9.3635
#
# -----Epoch: 26/75 Batch: 2800/64-----
# Discriminator loss on real data: 0.0774
# Discriminator loss on fake data: 0.0198
# Generator loss: 5.3814
#
# -----Epoch: 26/75 Batch: 2900/64-----
# Discriminator loss on real data: 0.0003
# Discriminator loss on fake data: 0.0051
# Generator loss: 6.9639
#
# -----Epoch: 26/75 Batch: 3000/64-----
# Discriminator loss on real data: 0.0455
# Discriminator loss on fake data: 0.0004
# Generator loss: 10.4769
#
# -----Epoch: 26/75 Batch: 3100/64-----
# Discriminator loss on real data: 0.0117
# Discriminator loss on fake data: 0.0021
# Generator loss: 10.2346
#
# -----Epoch: 27/75 Batch: 0/64-----
# Discriminator loss on real data: 0.0345
# Discriminator loss on fake data: 0.0005
# Generator loss: 10.2725
#
# -----Epoch: 27/75 Batch: 100/64-----
# Discriminator loss on real data: 0.0414
# Discriminator loss on fake data: 0.0025
# Generator loss: 8.1116
#
# -----Epoch: 27/75 Batch: 200/64-----
# Discriminator loss on real data: 0.0129
# Discriminator loss on fake data: 0.2942
# Generator loss: 5.8163
#
# -----Epoch: 27/75 Batch: 300/64-----
# Discriminator loss on real data: 0.2246
# Discriminator loss on fake data: 0.0001
# Generator loss: 10.9920
#
# -----Epoch: 27/75 Batch: 400/64-----
# Discriminator loss on real data: 0.0512
# Discriminator loss on fake data: 0.0618
# Generator loss: 5.0880
#
# -----Epoch: 27/75 Batch: 500/64-----
# Discriminator loss on real data: 0.0697
# Discriminator loss on fake data: 0.0094
# Generator loss: 8.9551
#
# -----Epoch: 27/75 Batch: 600/64-----
# Discriminator loss on real data: 0.0006
# Discriminator loss on fake data: 0.0009
# Generator loss: 9.9696
#
# -----Epoch: 27/75 Batch: 700/64-----
# Discriminator loss on real data: 0.0007
# Discriminator loss on fake data: 0.0028
# Generator loss: 7.9203
#
# -----Epoch: 27/75 Batch: 800/64-----
# Discriminator loss on real data: 0.0059
# Discriminator loss on fake data: 0.0066
# Generator loss: 6.8477
#
# -----Epoch: 27/75 Batch: 900/64-----
# Discriminator loss on real data: 0.0098
# Discriminator loss on fake data: 0.0003
# Generator loss: 14.6808
#
# -----Epoch: 27/75 Batch: 1000/64-----
# Discriminator loss on real data: 0.0253
# Discriminator loss on fake data: 0.0193
# Generator loss: 7.5894
#
# -----Epoch: 27/75 Batch: 1100/64-----
# Discriminator loss on real data: 0.0003
# Discriminator loss on fake data: 0.0110
# Generator loss: 8.8867
#
# -----Epoch: 27/75 Batch: 1200/64-----
# Discriminator loss on real data: 0.2772
# Discriminator loss on fake data: 0.0005
# Generator loss: 6.6303
#
# -----Epoch: 27/75 Batch: 1300/64-----
# Discriminator loss on real data: 0.0097
# Discriminator loss on fake data: 0.0328
# Generator loss: 6.7811
#
# -----Epoch: 27/75 Batch: 1400/64-----
# Discriminator loss on real data: 0.0290
# Discriminator loss on fake data: 0.0440
# Generator loss: 4.0033
#
# -----Epoch: 27/75 Batch: 1500/64-----
# Discriminator loss on real data: 0.0059
# Discriminator loss on fake data: 0.1949
# Generator loss: 6.4234
#
# -----Epoch: 27/75 Batch: 1600/64-----
# Discriminator loss on real data: 0.0192
# Discriminator loss on fake data: 0.0325
# Generator loss: 6.2690
#
# -----Epoch: 27/75 Batch: 1700/64-----
# Discriminator loss on real data: 0.0002
# Discriminator loss on fake data: 0.0131
# Generator loss: 7.8773
#
# -----Epoch: 27/75 Batch: 1800/64-----
# Discriminator loss on real data: 0.0002
# Discriminator loss on fake data: 0.0318
# Generator loss: 6.5880
#
# -----Epoch: 27/75 Batch: 1900/64-----
# Discriminator loss on real data: 0.0564
# Discriminator loss on fake data: 0.0009
# Generator loss: 8.1036
#
# -----Epoch: 27/75 Batch: 2000/64-----
# Discriminator loss on real data: 0.0004
# Discriminator loss on fake data: 0.1075
# Generator loss: 6.1790
#
# -----Epoch: 27/75 Batch: 2100/64-----
# Discriminator loss on real data: 0.2761
# Discriminator loss on fake data: 0.0151
# Generator loss: 9.5030
#
# -----Epoch: 27/75 Batch: 2200/64-----
# Discriminator loss on real data: 0.0659
# Discriminator loss on fake data: 0.0289
# Generator loss: 6.3894
#
# -----Epoch: 27/75 Batch: 2300/64-----
# Discriminator loss on real data: 0.0000
# Discriminator loss on fake data: 0.0052
# Generator loss: 8.9867
#
# -----Epoch: 27/75 Batch: 2400/64-----
# Discriminator loss on real data: 0.0061
# Discriminator loss on fake data: 0.0005
# Generator loss: 7.5036
#
# -----Epoch: 27/75 Batch: 2500/64-----
# Discriminator loss on real data: 0.0077
# Discriminator loss on fake data: 0.0045
# Generator loss: 8.7011
#
# -----Epoch: 27/75 Batch: 2600/64-----
# Discriminator loss on real data: 0.0003
# Discriminator loss on fake data: 0.0056
# Generator loss: 8.2958
#
# -----Epoch: 27/75 Batch: 2700/64-----
# Discriminator loss on real data: 0.0131
# Discriminator loss on fake data: 0.0001
# Generator loss: 12.3134
#
# -----Epoch: 27/75 Batch: 2800/64-----
# Discriminator loss on real data: 0.0013
# Discriminator loss on fake data: 0.0635
# Generator loss: 7.4094
#
# -----Epoch: 27/75 Batch: 2900/64-----
# Discriminator loss on real data: 0.0812
# Discriminator loss on fake data: 0.0297
# Generator loss: 6.1222
#
# -----Epoch: 27/75 Batch: 3000/64-----
# Discriminator loss on real data: 0.0009
# Discriminator loss on fake data: 0.0033
# Generator loss: 7.3290
#
# -----Epoch: 27/75 Batch: 3100/64-----
# Discriminator loss on real data: 0.0001
# Discriminator loss on fake data: 0.0015
# Generator loss: 8.1497
#
# -----Epoch: 28/75 Batch: 0/64-----
# Discriminator loss on real data: 0.0031
# Discriminator loss on fake data: 0.0015
# Generator loss: 9.7403
#
# -----Epoch: 28/75 Batch: 100/64-----
# Discriminator loss on real data: 0.2979
# Discriminator loss on fake data: 0.0036
# Generator loss: 6.0866
#
# -----Epoch: 28/75 Batch: 200/64-----
# Discriminator loss on real data: 0.0679
# Discriminator loss on fake data: 0.0019
# Generator loss: 9.7662
#
# -----Epoch: 28/75 Batch: 300/64-----
# Discriminator loss on real data: 0.0008
# Discriminator loss on fake data: 0.0333
# Generator loss: 10.8579
#
# -----Epoch: 28/75 Batch: 400/64-----
# Discriminator loss on real data: 0.0000
# Discriminator loss on fake data: 1.2327
# Generator loss: 5.9403
#
# -----Epoch: 28/75 Batch: 500/64-----
# Discriminator loss on real data: 0.0070
# Discriminator loss on fake data: 0.0182
# Generator loss: 7.3641
#
# -----Epoch: 28/75 Batch: 600/64-----
# Discriminator loss on real data: 0.0082
# Discriminator loss on fake data: 0.0029
# Generator loss: 8.4762
#
# -----Epoch: 28/75 Batch: 700/64-----
# Discriminator loss on real data: 0.0245
# Discriminator loss on fake data: 0.0056
# Generator loss: 5.9631
#
# -----Epoch: 28/75 Batch: 800/64-----
# Discriminator loss on real data: 0.0001
# Discriminator loss on fake data: 0.3876
# Generator loss: 9.1167
#
# -----Epoch: 28/75 Batch: 900/64-----
# Discriminator loss on real data: 0.0006
# Discriminator loss on fake data: 0.0344
# Generator loss: 5.9067
#
# -----Epoch: 28/75 Batch: 1000/64-----
# Discriminator loss on real data: 0.0119
# Discriminator loss on fake data: 0.0063
# Generator loss: 10.8449
# -----Epoch: 28/75 Batch: 1100/64-----
# Discriminator loss on real data: 0.1672
# Discriminator loss on fake data: 0.0070
# Generator loss: 7.3242
#
# -----Epoch: 28/75 Batch: 1200/64-----
# Discriminator loss on real data: 0.0136
# Discriminator loss on fake data: 0.0028
# Generator loss: 8.6809
#
# -----Epoch: 28/75 Batch: 1300/64-----
# Discriminator loss on real data: 0.0020
# Discriminator loss on fake data: 0.0403
# Generator loss: 7.4091
#
# -----Epoch: 28/75 Batch: 1400/64-----
# Discriminator loss on real data: 0.0018
# Discriminator loss on fake data: 0.0225
# Generator loss: 6.9924
#
# -----Epoch: 28/75 Batch: 1500/64-----
# Discriminator loss on real data: 0.0010
# Discriminator loss on fake data: 0.0005
# Generator loss: 10.3401
#
# -----Epoch: 28/75 Batch: 1600/64-----
# Discriminator loss on real data: 0.0001
# Discriminator loss on fake data: 0.0411
# Generator loss: 7.3460
#
# -----Epoch: 28/75 Batch: 1700/64-----
# Discriminator loss on real data: 0.0016
# Discriminator loss on fake data: 0.0216
# Generator loss: 8.3997
#
# -----Epoch: 28/75 Batch: 1800/64-----
# Discriminator loss on real data: 0.0005
# Discriminator loss on fake data: 0.1000
# Generator loss: 6.5663
#
# -----Epoch: 28/75 Batch: 1900/64-----
# Discriminator loss on real data: 0.0010
# Discriminator loss on fake data: 0.0068
# Generator loss: 8.7454
#
# -----Epoch: 28/75 Batch: 2000/64-----
# Discriminator loss on real data: 0.0139
# Discriminator loss on fake data: 0.0174
# Generator loss: 6.5046
#
# -----Epoch: 28/75 Batch: 2100/64-----
# Discriminator loss on real data: 0.0000
# Discriminator loss on fake data: 1.4607
# Generator loss: 7.3806
#
# -----Epoch: 28/75 Batch: 2200/64-----
# Discriminator loss on real data: 0.0815
# Discriminator loss on fake data: 0.0037
# Generator loss: 7.7125
#
# -----Epoch: 28/75 Batch: 2300/64-----
# Discriminator loss on real data: 0.0001
# Discriminator loss on fake data: 0.0114
# Generator loss: 7.9382
#
# -----Epoch: 28/75 Batch: 2400/64-----
# Discriminator loss on real data: 0.0000
# Discriminator loss on fake data: 0.0247
# Generator loss: 10.1641
#
# -----Epoch: 28/75 Batch: 2500/64-----
# Discriminator loss on real data: 0.0002
# Discriminator loss on fake data: 0.0008
# Generator loss: 8.4973

# %%
noise = torch.randn(4, GEN_IN, 1, 1).cuda()
out = gen(noise).cpu().detach().numpy()

print('Magic: ')

for idx, T in enumerate(out):
    plt.subplot(2, 2, idx+1)
    plt.imshow(T.squeeze(0))
